# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import joblib

# Load the dataset
file_path = '../dataset/BodyFat - Extended.csv'
data = pd.read_csv(file_path)

data = data[data['Sex'] == 'F']

# Separate features and target variable
X = data[['Height', 'Neck', 'Abdomen']]
y = data["BodyFat"]

# Normalize the numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
joblib.dump(scaler, '../scalers/women_scaler.joblib')
# Out:
# ['../scalers/women_scaler.joblib']

# %%
checkpoint_filepath = '../models/men_best_model_weights.h5'
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_mean_absolute_error',
    mode='min',          # Save the model with minimum mean absolute error
    verbose=1
)

# Define the deep learning model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(256, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=16,
    callbacks=[checkpoint_callback],
    verbose=1
)
# Out:
# Epoch 1/100
# 1/8 [==>...........................] - ETA: 14s - loss: 566.5793 - mean_absolute_error: 22.9495
# Epoch 1: val_mean_absolute_error improved from inf to 17.97843, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 2s 68ms/step - loss: 477.3602 - mean_absolute_error: 21.0241 - val_loss: 367.7954 - val_mean_absolute_error: 17.9784
# Epoch 2/100
# 1/8 [==>...........................] - ETA: 0s - loss: 439.3492 - mean_absolute_error: 19.8320
# Epoch 2: val_mean_absolute_error improved from 17.97843 to 9.75123, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 21ms/step - loss: 222.6415 - mean_absolute_error: 12.8171 - val_loss: 208.0731 - val_mean_absolute_error: 9.7512
# Epoch 3/100
# 1/8 [==>...........................] - ETA: 0s - loss: 150.7992 - mean_absolute_error: 9.3087
# Epoch 3: val_mean_absolute_error improved from 9.75123 to 9.59241, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 22ms/step - loss: 110.4183 - mean_absolute_error: 8.7532 - val_loss: 115.0732 - val_mean_absolute_error: 9.5924
# Epoch 4/100
# 1/8 [==>...........................] - ETA: 0s - loss: 75.1977 - mean_absolute_error: 6.2363
# Epoch 4: val_mean_absolute_error improved from 9.59241 to 6.96450, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 21ms/step - loss: 102.1939 - mean_absolute_error: 8.5273 - val_loss: 79.8605 - val_mean_absolute_error: 6.9645
# Epoch 5/100
# 1/8 [==>...........................] - ETA: 0s - loss: 89.0969 - mean_absolute_error: 8.0135
# Epoch 5: val_mean_absolute_error did not improve from 6.96450
# 8/8 [==============================] - 0s 12ms/step - loss: 68.4121 - mean_absolute_error: 6.8844 - val_loss: 71.4981 - val_mean_absolute_error: 7.4094
# Epoch 6/100
# 1/8 [==>...........................] - ETA: 0s - loss: 46.1491 - mean_absolute_error: 5.7074
# Epoch 6: val_mean_absolute_error improved from 6.96450 to 6.58829, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 22ms/step - loss: 58.9930 - mean_absolute_error: 6.1732 - val_loss: 74.3723 - val_mean_absolute_error: 6.5883
# Epoch 7/100
# 1/8 [==>...........................] - ETA: 0s - loss: 52.0604 - mean_absolute_error: 6.1397
# Epoch 7: val_mean_absolute_error did not improve from 6.58829
# 8/8 [==============================] - 0s 12ms/step - loss: 50.1170 - mean_absolute_error: 5.6515 - val_loss: 59.2224 - val_mean_absolute_error: 6.5885
# Epoch 8/100
# 1/8 [==>...........................] - ETA: 0s - loss: 45.2351 - mean_absolute_error: 4.6155
# Epoch 8: val_mean_absolute_error improved from 6.58829 to 5.45825, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 21ms/step - loss: 51.6507 - mean_absolute_error: 5.8359 - val_loss: 53.4946 - val_mean_absolute_error: 5.4582
# Epoch 9/100
# 1/8 [==>...........................] - ETA: 0s - loss: 42.2872 - mean_absolute_error: 5.3763
# Epoch 9: val_mean_absolute_error did not improve from 5.45825
# 8/8 [==============================] - 0s 12ms/step - loss: 48.4219 - mean_absolute_error: 5.5180 - val_loss: 50.6022 - val_mean_absolute_error: 6.0727
# Epoch 10/100
# 1/8 [==>...........................] - ETA: 0s - loss: 33.2774 - mean_absolute_error: 5.1140
# Epoch 10: val_mean_absolute_error improved from 5.45825 to 5.45537, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 22ms/step - loss: 38.2982 - mean_absolute_error: 4.8649 - val_loss: 54.5687 - val_mean_absolute_error: 5.4554
# Epoch 11/100
# 1/8 [==>...........................] - ETA: 0s - loss: 34.2379 - mean_absolute_error: 4.8727
# Epoch 11: val_mean_absolute_error improved from 5.45537 to 5.33011, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 21ms/step - loss: 32.6239 - mean_absolute_error: 4.4499 - val_loss: 44.8752 - val_mean_absolute_error: 5.3301
# Epoch 12/100
# 1/8 [==>...........................] - ETA: 0s - loss: 29.1482 - mean_absolute_error: 4.0394
# Epoch 12: val_mean_absolute_error improved from 5.33011 to 4.80961, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 22ms/step - loss: 30.2086 - mean_absolute_error: 4.3573 - val_loss: 44.3455 - val_mean_absolute_error: 4.8096
# Epoch 13/100
# 1/8 [==>...........................] - ETA: 0s - loss: 30.1367 - mean_absolute_error: 4.1329
# Epoch 13: val_mean_absolute_error did not improve from 4.80961
# 8/8 [==============================] - 0s 12ms/step - loss: 26.3354 - mean_absolute_error: 3.9301 - val_loss: 38.0984 - val_mean_absolute_error: 5.0495
# Epoch 14/100
# 1/8 [==>...........................] - ETA: 0s - loss: 44.3045 - mean_absolute_error: 5.3537
# Epoch 14: val_mean_absolute_error improved from 4.80961 to 4.74585, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 22ms/step - loss: 25.7257 - mean_absolute_error: 3.9030 - val_loss: 43.0521 - val_mean_absolute_error: 4.7458
# Epoch 15/100
# 1/8 [==>...........................] - ETA: 0s - loss: 18.2641 - mean_absolute_error: 3.3768
# Epoch 15: val_mean_absolute_error did not improve from 4.74585
# 8/8 [==============================] - 0s 12ms/step - loss: 24.2058 - mean_absolute_error: 3.7995 - val_loss: 37.6533 - val_mean_absolute_error: 5.0925
# Epoch 16/100
# 1/8 [==>...........................] - ETA: 0s - loss: 29.9206 - mean_absolute_error: 4.1712
# Epoch 16: val_mean_absolute_error improved from 4.74585 to 4.63712, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 21ms/step - loss: 21.5131 - mean_absolute_error: 3.5817 - val_loss: 38.6200 - val_mean_absolute_error: 4.6371
# Epoch 17/100
# 1/8 [==>...........................] - ETA: 0s - loss: 18.6610 - mean_absolute_error: 3.4952
# Epoch 17: val_mean_absolute_error improved from 4.63712 to 4.30379, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 22ms/step - loss: 20.3844 - mean_absolute_error: 3.5012 - val_loss: 30.5711 - val_mean_absolute_error: 4.3038
# Epoch 18/100
# 1/8 [==>...........................] - ETA: 0s - loss: 13.2747 - mean_absolute_error: 3.1425
# Epoch 18: val_mean_absolute_error did not improve from 4.30379
# 8/8 [==============================] - 0s 12ms/step - loss: 19.4429 - mean_absolute_error: 3.5460 - val_loss: 30.9434 - val_mean_absolute_error: 4.5385
# Epoch 19/100
# 1/8 [==>...........................] - ETA: 0s - loss: 20.4722 - mean_absolute_error: 3.5737
# Epoch 19: val_mean_absolute_error did not improve from 4.30379
# 8/8 [==============================] - 0s 12ms/step - loss: 22.0445 - mean_absolute_error: 3.8784 - val_loss: 38.2620 - val_mean_absolute_error: 4.8459
# Epoch 20/100
# 1/8 [==>...........................] - ETA: 0s - loss: 14.4292 - mean_absolute_error: 3.1280
# Epoch 20: val_mean_absolute_error did not improve from 4.30379
# 8/8 [==============================] - 0s 12ms/step - loss: 16.6353 - mean_absolute_error: 3.2216 - val_loss: 29.1537 - val_mean_absolute_error: 4.4828
# Epoch 21/100
# 1/8 [==>...........................] - ETA: 0s - loss: 27.5924 - mean_absolute_error: 4.2659
# Epoch 21: val_mean_absolute_error improved from 4.30379 to 4.26381, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 25ms/step - loss: 16.1007 - mean_absolute_error: 3.0760 - val_loss: 28.1287 - val_mean_absolute_error: 4.2638
# Epoch 22/100
# 1/8 [==>...........................] - ETA: 0s - loss: 9.3300 - mean_absolute_error: 2.2774
# Epoch 22: val_mean_absolute_error did not improve from 4.26381
# 8/8 [==============================] - 0s 12ms/step - loss: 15.2910 - mean_absolute_error: 3.0748 - val_loss: 32.8551 - val_mean_absolute_error: 4.5773
# Epoch 23/100
# 1/8 [==>...........................] - ETA: 0s - loss: 22.0098 - mean_absolute_error: 3.5134
# Epoch 23: val_mean_absolute_error did not improve from 4.26381
# 8/8 [==============================] - 0s 12ms/step - loss: 14.3484 - mean_absolute_error: 2.9723 - val_loss: 27.3940 - val_mean_absolute_error: 4.2913
# Epoch 24/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.6149 - mean_absolute_error: 2.8679
# Epoch 24: val_mean_absolute_error did not improve from 4.26381
# 8/8 [==============================] - 0s 12ms/step - loss: 14.5691 - mean_absolute_error: 2.9490 - val_loss: 28.4623 - val_mean_absolute_error: 4.3166
# Epoch 25/100
# 1/8 [==>...........................] - ETA: 0s - loss: 11.1979 - mean_absolute_error: 2.6604
# Epoch 25: val_mean_absolute_error improved from 4.26381 to 4.05044, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 21ms/step - loss: 13.4869 - mean_absolute_error: 2.9258 - val_loss: 24.7956 - val_mean_absolute_error: 4.0504
# Epoch 26/100
# 1/8 [==>...........................] - ETA: 0s - loss: 3.7669 - mean_absolute_error: 1.6609
# Epoch 26: val_mean_absolute_error did not improve from 4.05044
# 8/8 [==============================] - 0s 12ms/step - loss: 12.7943 - mean_absolute_error: 2.8030 - val_loss: 25.0432 - val_mean_absolute_error: 4.0691
# Epoch 27/100
# 1/8 [==>...........................] - ETA: 0s - loss: 15.4897 - mean_absolute_error: 2.8214
# Epoch 27: val_mean_absolute_error did not improve from 4.05044
# 8/8 [==============================] - 0s 12ms/step - loss: 12.9268 - mean_absolute_error: 2.8120 - val_loss: 27.3232 - val_mean_absolute_error: 4.2371
# Epoch 28/100
# 1/8 [==>...........................] - ETA: 0s - loss: 6.3712 - mean_absolute_error: 1.8375
# Epoch 28: val_mean_absolute_error did not improve from 4.05044
# 8/8 [==============================] - 0s 11ms/step - loss: 13.7808 - mean_absolute_error: 2.8553 - val_loss: 26.7687 - val_mean_absolute_error: 4.1873
# Epoch 29/100
# 1/8 [==>...........................] - ETA: 0s - loss: 11.2485 - mean_absolute_error: 2.8111
# Epoch 29: val_mean_absolute_error did not improve from 4.05044
# 8/8 [==============================] - 0s 12ms/step - loss: 12.6485 - mean_absolute_error: 2.7462 - val_loss: 25.4479 - val_mean_absolute_error: 4.1083
# Epoch 30/100
# 1/8 [==>...........................] - ETA: 0s - loss: 17.2272 - mean_absolute_error: 3.1798
# Epoch 30: val_mean_absolute_error improved from 4.05044 to 3.94245, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 20ms/step - loss: 12.0061 - mean_absolute_error: 2.6936 - val_loss: 23.1512 - val_mean_absolute_error: 3.9424
# Epoch 31/100
# 1/8 [==>...........................] - ETA: 0s - loss: 16.4643 - mean_absolute_error: 3.2738
# Epoch 31: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 12ms/step - loss: 12.4381 - mean_absolute_error: 2.7917 - val_loss: 29.7716 - val_mean_absolute_error: 4.5016
# Epoch 32/100
# 1/8 [==>...........................] - ETA: 0s - loss: 17.7515 - mean_absolute_error: 3.4134
# Epoch 32: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 11ms/step - loss: 13.5539 - mean_absolute_error: 2.9056 - val_loss: 26.1111 - val_mean_absolute_error: 4.1794
# Epoch 33/100
# 1/8 [==>...........................] - ETA: 0s - loss: 17.1962 - mean_absolute_error: 3.1953
# Epoch 33: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 13ms/step - loss: 15.0343 - mean_absolute_error: 3.0166 - val_loss: 28.4357 - val_mean_absolute_error: 4.3449
# Epoch 34/100
# 1/8 [==>...........................] - ETA: 0s - loss: 7.2141 - mean_absolute_error: 2.0265
# Epoch 34: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 12ms/step - loss: 12.5294 - mean_absolute_error: 2.8328 - val_loss: 26.3000 - val_mean_absolute_error: 4.1819
# Epoch 35/100
# 1/8 [==>...........................] - ETA: 0s - loss: 17.3734 - mean_absolute_error: 3.2556
# Epoch 35: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 11ms/step - loss: 13.2098 - mean_absolute_error: 2.8512 - val_loss: 25.5177 - val_mean_absolute_error: 4.0712
# Epoch 36/100
# 1/8 [==>...........................] - ETA: 0s - loss: 14.2037 - mean_absolute_error: 3.1568
# Epoch 36: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 12ms/step - loss: 13.4018 - mean_absolute_error: 2.8543 - val_loss: 23.9811 - val_mean_absolute_error: 3.9901
# Epoch 37/100
# 1/8 [==>...........................] - ETA: 0s - loss: 9.6938 - mean_absolute_error: 2.5631
# Epoch 37: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 11ms/step - loss: 13.9473 - mean_absolute_error: 2.9640 - val_loss: 26.8869 - val_mean_absolute_error: 4.2039
# Epoch 38/100
# 1/8 [==>...........................] - ETA: 0s - loss: 10.3842 - mean_absolute_error: 2.5881
# Epoch 38: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 11ms/step - loss: 14.2790 - mean_absolute_error: 3.0318 - val_loss: 30.7670 - val_mean_absolute_error: 4.6514
# Epoch 39/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.3137 - mean_absolute_error: 2.7980
# Epoch 39: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 11ms/step - loss: 13.1841 - mean_absolute_error: 2.9357 - val_loss: 26.1814 - val_mean_absolute_error: 4.1408
# Epoch 40/100
# 1/8 [==>...........................] - ETA: 0s - loss: 10.7012 - mean_absolute_error: 2.7831
# Epoch 40: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 11ms/step - loss: 11.7351 - mean_absolute_error: 2.5898 - val_loss: 27.0837 - val_mean_absolute_error: 4.1795
# Epoch 41/100
# 1/8 [==>...........................] - ETA: 0s - loss: 11.9740 - mean_absolute_error: 2.7851
# Epoch 41: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 11ms/step - loss: 12.0681 - mean_absolute_error: 2.6954 - val_loss: 24.5843 - val_mean_absolute_error: 4.0259
# Epoch 42/100
# 1/8 [==>...........................] - ETA: 0s - loss: 9.1645 - mean_absolute_error: 2.3513
# Epoch 42: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 12ms/step - loss: 11.2059 - mean_absolute_error: 2.6380 - val_loss: 26.4580 - val_mean_absolute_error: 4.2151
# Epoch 43/100
# 1/8 [==>...........................] - ETA: 0s - loss: 15.6058 - mean_absolute_error: 2.9438
# Epoch 43: val_mean_absolute_error did not improve from 3.94245
# 8/8 [==============================] - 0s 13ms/step - loss: 11.7897 - mean_absolute_error: 2.6285 - val_loss: 25.0439 - val_mean_absolute_error: 4.1143
# Epoch 44/100
# 1/8 [==>...........................] - ETA: 0s - loss: 21.4406 - mean_absolute_error: 3.7252
# Epoch 44: val_mean_absolute_error improved from 3.94245 to 3.91182, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 21ms/step - loss: 12.1452 - mean_absolute_error: 2.7145 - val_loss: 23.4405 - val_mean_absolute_error: 3.9118
# Epoch 45/100
# 1/8 [==>...........................] - ETA: 0s - loss: 9.7052 - mean_absolute_error: 2.3854
# Epoch 45: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 11.5450 - mean_absolute_error: 2.5769 - val_loss: 24.4734 - val_mean_absolute_error: 3.9872
# Epoch 46/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.6339 - mean_absolute_error: 2.5851
# Epoch 46: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 11.8104 - mean_absolute_error: 2.7101 - val_loss: 26.7306 - val_mean_absolute_error: 4.1809
# Epoch 47/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.0532 - mean_absolute_error: 2.3710
# Epoch 47: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 14ms/step - loss: 11.0844 - mean_absolute_error: 2.5518 - val_loss: 34.7359 - val_mean_absolute_error: 4.8767
# Epoch 48/100
# 1/8 [==>...........................] - ETA: 0s - loss: 18.9441 - mean_absolute_error: 3.5457
# Epoch 48: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 15ms/step - loss: 12.7917 - mean_absolute_error: 2.8437 - val_loss: 26.5011 - val_mean_absolute_error: 4.1892
# Epoch 49/100
# 1/8 [==>...........................] - ETA: 0s - loss: 14.1593 - mean_absolute_error: 3.1274
# Epoch 49: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 11.9879 - mean_absolute_error: 2.6147 - val_loss: 25.6012 - val_mean_absolute_error: 4.0790
# Epoch 50/100
# 1/8 [==>...........................] - ETA: 0s - loss: 14.3844 - mean_absolute_error: 2.7226
# Epoch 50: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 11.3629 - mean_absolute_error: 2.5772 - val_loss: 23.6378 - val_mean_absolute_error: 3.9143
# Epoch 51/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.0631 - mean_absolute_error: 2.2443
# Epoch 51: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 10.5878 - mean_absolute_error: 2.5085 - val_loss: 24.7430 - val_mean_absolute_error: 4.0061
# Epoch 52/100
# 1/8 [==>...........................] - ETA: 0s - loss: 14.1371 - mean_absolute_error: 3.0368
# Epoch 52: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 10.6198 - mean_absolute_error: 2.5240 - val_loss: 25.2398 - val_mean_absolute_error: 4.0751
# Epoch 53/100
# 1/8 [==>...........................] - ETA: 0s - loss: 6.7014 - mean_absolute_error: 1.9295
# Epoch 53: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 10.7317 - mean_absolute_error: 2.4838 - val_loss: 25.0442 - val_mean_absolute_error: 4.0316
# Epoch 54/100
# 1/8 [==>...........................] - ETA: 0s - loss: 11.7985 - mean_absolute_error: 2.5490
# Epoch 54: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 11.9911 - mean_absolute_error: 2.7108 - val_loss: 25.7380 - val_mean_absolute_error: 4.0869
# Epoch 55/100
# 1/8 [==>...........................] - ETA: 0s - loss: 7.8805 - mean_absolute_error: 2.3436
# Epoch 55: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 13ms/step - loss: 11.4210 - mean_absolute_error: 2.7017 - val_loss: 31.6570 - val_mean_absolute_error: 4.6341
# Epoch 56/100
# 1/8 [==>...........................] - ETA: 0s - loss: 18.3529 - mean_absolute_error: 3.5033
# Epoch 56: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 10.8615 - mean_absolute_error: 2.5787 - val_loss: 27.2212 - val_mean_absolute_error: 4.2525
# Epoch 57/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.9946 - mean_absolute_error: 2.0880
# Epoch 57: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 10.4263 - mean_absolute_error: 2.5088 - val_loss: 24.3942 - val_mean_absolute_error: 3.9634
# Epoch 58/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.4602 - mean_absolute_error: 2.8739
# Epoch 58: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 13ms/step - loss: 10.4660 - mean_absolute_error: 2.5126 - val_loss: 24.6270 - val_mean_absolute_error: 4.0220
# Epoch 59/100
# 1/8 [==>...........................] - ETA: 0s - loss: 7.3301 - mean_absolute_error: 2.0643
# Epoch 59: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 10.1205 - mean_absolute_error: 2.3786 - val_loss: 25.9899 - val_mean_absolute_error: 4.1490
# Epoch 60/100
# 1/8 [==>...........................] - ETA: 0s - loss: 7.5710 - mean_absolute_error: 1.9743
# Epoch 60: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 10.2386 - mean_absolute_error: 2.5036 - val_loss: 31.0013 - val_mean_absolute_error: 4.6772
# Epoch 61/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.1971 - mean_absolute_error: 2.2050
# Epoch 61: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 10.6549 - mean_absolute_error: 2.4937 - val_loss: 27.6250 - val_mean_absolute_error: 4.2829
# Epoch 62/100
# 1/8 [==>...........................] - ETA: 0s - loss: 11.1395 - mean_absolute_error: 2.6529
# Epoch 62: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 10.6546 - mean_absolute_error: 2.5135 - val_loss: 25.2398 - val_mean_absolute_error: 4.0583
# Epoch 63/100
# 1/8 [==>...........................] - ETA: 0s - loss: 13.0159 - mean_absolute_error: 2.4482
# Epoch 63: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 13.4372 - mean_absolute_error: 2.8992 - val_loss: 28.4437 - val_mean_absolute_error: 4.3165
# Epoch 64/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.8709 - mean_absolute_error: 2.1803
# Epoch 64: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 13.5489 - mean_absolute_error: 2.8308 - val_loss: 34.4675 - val_mean_absolute_error: 4.7279
# Epoch 65/100
# 1/8 [==>...........................] - ETA: 0s - loss: 20.1268 - mean_absolute_error: 3.6913
# Epoch 65: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 12ms/step - loss: 13.3103 - mean_absolute_error: 2.8069 - val_loss: 28.2497 - val_mean_absolute_error: 4.2722
# Epoch 66/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.0891 - mean_absolute_error: 2.9017
# Epoch 66: val_mean_absolute_error did not improve from 3.91182
# 8/8 [==============================] - 0s 11ms/step - loss: 10.0639 - mean_absolute_error: 2.4265 - val_loss: 26.8470 - val_mean_absolute_error: 4.1465
# Epoch 67/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.3433 - mean_absolute_error: 2.3688
# Epoch 67: val_mean_absolute_error improved from 3.91182 to 3.86683, saving model to ../models/men_best_model_weights.h5
# 8/8 [==============================] - 0s 25ms/step - loss: 12.0410 - mean_absolute_error: 2.6228 - val_loss: 23.5714 - val_mean_absolute_error: 3.8668
# Epoch 68/100
# 1/8 [==>...........................] - ETA: 0s - loss: 6.9767 - mean_absolute_error: 2.2628
# Epoch 68: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 14.6177 - mean_absolute_error: 2.9928 - val_loss: 39.0656 - val_mean_absolute_error: 5.0580
# Epoch 69/100
# 1/8 [==>...........................] - ETA: 0s - loss: 16.4421 - mean_absolute_error: 3.2893
# Epoch 69: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 13ms/step - loss: 13.8250 - mean_absolute_error: 2.9770 - val_loss: 30.1442 - val_mean_absolute_error: 4.4575
# Epoch 70/100
# 1/8 [==>...........................] - ETA: 0s - loss: 13.2575 - mean_absolute_error: 3.0678
# Epoch 70: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 11.1815 - mean_absolute_error: 2.5522 - val_loss: 27.2201 - val_mean_absolute_error: 4.2730
# Epoch 71/100
# 1/8 [==>...........................] - ETA: 0s - loss: 7.7378 - mean_absolute_error: 2.3984
# Epoch 71: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 10.5031 - mean_absolute_error: 2.5563 - val_loss: 26.1283 - val_mean_absolute_error: 4.0751
# Epoch 72/100
# 1/8 [==>...........................] - ETA: 0s - loss: 5.8755 - mean_absolute_error: 1.9799
# Epoch 72: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 10.1330 - mean_absolute_error: 2.3972 - val_loss: 26.2684 - val_mean_absolute_error: 4.1300
# Epoch 73/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.9063 - mean_absolute_error: 2.7471
# Epoch 73: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 13ms/step - loss: 9.8401 - mean_absolute_error: 2.4601 - val_loss: 33.0200 - val_mean_absolute_error: 4.7672
# Epoch 74/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.8927 - mean_absolute_error: 1.9890
# Epoch 74: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 10.1212 - mean_absolute_error: 2.4456 - val_loss: 26.4984 - val_mean_absolute_error: 4.1807
# Epoch 75/100
# 1/8 [==>...........................] - ETA: 0s - loss: 13.3784 - mean_absolute_error: 3.0300
# Epoch 75: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.5232 - mean_absolute_error: 2.3205 - val_loss: 25.5792 - val_mean_absolute_error: 4.0651
# Epoch 76/100
# 1/8 [==>...........................] - ETA: 0s - loss: 11.1652 - mean_absolute_error: 2.7044
# Epoch 76: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.0504 - mean_absolute_error: 2.3390 - val_loss: 26.5757 - val_mean_absolute_error: 4.1829
# Epoch 77/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.0280 - mean_absolute_error: 2.3089
# Epoch 77: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.2786 - mean_absolute_error: 2.3545 - val_loss: 25.7531 - val_mean_absolute_error: 3.9984
# Epoch 78/100
# 1/8 [==>...........................] - ETA: 0s - loss: 6.2706 - mean_absolute_error: 2.0764
# Epoch 78: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.1810 - mean_absolute_error: 2.3186 - val_loss: 25.1655 - val_mean_absolute_error: 3.9988
# Epoch 79/100
# 1/8 [==>...........................] - ETA: 0s - loss: 5.5523 - mean_absolute_error: 1.8375
# Epoch 79: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 11ms/step - loss: 8.8564 - mean_absolute_error: 2.2336 - val_loss: 27.7266 - val_mean_absolute_error: 4.2969
# Epoch 80/100
# 1/8 [==>...........................] - ETA: 0s - loss: 4.9813 - mean_absolute_error: 1.7695
# Epoch 80: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 8.2662 - mean_absolute_error: 2.1672 - val_loss: 28.3919 - val_mean_absolute_error: 4.3834
# Epoch 81/100
# 1/8 [==>...........................] - ETA: 0s - loss: 9.0706 - mean_absolute_error: 2.4185
# Epoch 81: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 11ms/step - loss: 8.4689 - mean_absolute_error: 2.2199 - val_loss: 27.3545 - val_mean_absolute_error: 4.2071
# Epoch 82/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.9664 - mean_absolute_error: 2.5117
# Epoch 82: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 11ms/step - loss: 8.4121 - mean_absolute_error: 2.1814 - val_loss: 26.3289 - val_mean_absolute_error: 4.0785
# Epoch 83/100
# 1/8 [==>...........................] - ETA: 0s - loss: 4.1079 - mean_absolute_error: 1.4486
# Epoch 83: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.0728 - mean_absolute_error: 2.2767 - val_loss: 27.7755 - val_mean_absolute_error: 4.2341
# Epoch 84/100
# 1/8 [==>...........................] - ETA: 0s - loss: 5.2393 - mean_absolute_error: 1.9068
# Epoch 84: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 15ms/step - loss: 8.3969 - mean_absolute_error: 2.1804 - val_loss: 26.4503 - val_mean_absolute_error: 4.1301
# Epoch 85/100
# 1/8 [==>...........................] - ETA: 0s - loss: 13.8940 - mean_absolute_error: 2.7458
# Epoch 85: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.3866 - mean_absolute_error: 2.4511 - val_loss: 27.5905 - val_mean_absolute_error: 4.2823
# Epoch 86/100
# 1/8 [==>...........................] - ETA: 0s - loss: 18.7456 - mean_absolute_error: 3.6148
# Epoch 86: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.9132 - mean_absolute_error: 2.4274 - val_loss: 26.1133 - val_mean_absolute_error: 4.0817
# Epoch 87/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.8397 - mean_absolute_error: 2.6906
# Epoch 87: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.4320 - mean_absolute_error: 2.4348 - val_loss: 30.1654 - val_mean_absolute_error: 4.4890
# Epoch 88/100
# 1/8 [==>...........................] - ETA: 0s - loss: 14.8898 - mean_absolute_error: 3.2248
# Epoch 88: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 10.2997 - mean_absolute_error: 2.5164 - val_loss: 31.1529 - val_mean_absolute_error: 4.5337
# Epoch 89/100
# 1/8 [==>...........................] - ETA: 0s - loss: 9.4375 - mean_absolute_error: 2.4357
# Epoch 89: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 13ms/step - loss: 9.6970 - mean_absolute_error: 2.4674 - val_loss: 26.9867 - val_mean_absolute_error: 4.1718
# Epoch 90/100
# 1/8 [==>...........................] - ETA: 0s - loss: 13.0281 - mean_absolute_error: 2.8566
# Epoch 90: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 7.9487 - mean_absolute_error: 2.1611 - val_loss: 26.2973 - val_mean_absolute_error: 4.0968
# Epoch 91/100
# 1/8 [==>...........................] - ETA: 0s - loss: 5.9852 - mean_absolute_error: 1.8910
# Epoch 91: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 7.7791 - mean_absolute_error: 2.1122 - val_loss: 28.7758 - val_mean_absolute_error: 4.2452
# Epoch 92/100
# 1/8 [==>...........................] - ETA: 0s - loss: 6.7642 - mean_absolute_error: 2.3454
# Epoch 92: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 13ms/step - loss: 8.8670 - mean_absolute_error: 2.3316 - val_loss: 28.1004 - val_mean_absolute_error: 4.1863
# Epoch 93/100
# 1/8 [==>...........................] - ETA: 0s - loss: 4.6099 - mean_absolute_error: 1.6408
# Epoch 93: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.7429 - mean_absolute_error: 2.4678 - val_loss: 30.6753 - val_mean_absolute_error: 4.4747
# Epoch 94/100
# 1/8 [==>...........................] - ETA: 0s - loss: 3.0229 - mean_absolute_error: 1.3496
# Epoch 94: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 11ms/step - loss: 8.5803 - mean_absolute_error: 2.2127 - val_loss: 30.5161 - val_mean_absolute_error: 4.4596
# Epoch 95/100
# 1/8 [==>...........................] - ETA: 0s - loss: 5.5436 - mean_absolute_error: 1.8033
# Epoch 95: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 8.6378 - mean_absolute_error: 2.3039 - val_loss: 31.4532 - val_mean_absolute_error: 4.5866
# Epoch 96/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.0523 - mean_absolute_error: 1.9825
# Epoch 96: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.0363 - mean_absolute_error: 2.3595 - val_loss: 31.9477 - val_mean_absolute_error: 4.5240
# Epoch 97/100
# 1/8 [==>...........................] - ETA: 0s - loss: 8.8891 - mean_absolute_error: 2.2675
# Epoch 97: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.8441 - mean_absolute_error: 2.3097 - val_loss: 47.3788 - val_mean_absolute_error: 5.6237
# Epoch 98/100
# 1/8 [==>...........................] - ETA: 0s - loss: 12.9260 - mean_absolute_error: 3.0006
# Epoch 98: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 12.7800 - mean_absolute_error: 2.9763 - val_loss: 28.6814 - val_mean_absolute_error: 4.3458
# Epoch 99/100
# 1/8 [==>...........................] - ETA: 0s - loss: 10.5322 - mean_absolute_error: 2.7737
# Epoch 99: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 9.6233 - mean_absolute_error: 2.5668 - val_loss: 29.8522 - val_mean_absolute_error: 4.3623
# Epoch 100/100
# 1/8 [==>...........................] - ETA: 0s - loss: 10.8550 - mean_absolute_error: 2.7950
# Epoch 100: val_mean_absolute_error did not improve from 3.86683
# 8/8 [==============================] - 0s 12ms/step - loss: 11.3521 - mean_absolute_error: 2.6711 - val_loss: 31.6245 - val_mean_absolute_error: 4.4755

# %%
# Evaluate the model on the test set
model.load_weights(checkpoint_filepath)
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)

print(f"Test Loss: {test_loss}")
print(f"Test MAE: {test_mae}")
# Out:
# Test Loss: 14.867164611816406
# Test MAE: 2.8949899673461914

# %%
# Predict values for the test set
predicted_values = model.predict(X_test, verbose=0).flatten()
actual_values = y_test.values

# Calculate the differences (residuals)
differences = actual_values - predicted_values


lower_than_3 = 0
for diff in differences:
    if diff <= 3:
        lower_than_3 += 1
        
print(f'{lower_than_3 / len(differences) * 100:.2f}% of predictions have a difference of lower than three with actual values.')

# Define colors based on the threshold
colors = ['green' if -3 <= diff <= 3 else 'red' for diff in differences]

# Plot the differences as scatter points
plt.figure(figsize=(12, 6))
plt.scatter(range(len(differences)), differences, c=colors, alpha=0.7)
plt.axhline(y=-3, color='gray', linestyle='--', linewidth=1, alpha=0.7, label='Lower Threshold (-3)')
plt.axhline(y=3, color='gray', linestyle='--', linewidth=1, alpha=0.7, label='Upper Threshold (+3)')

# Add labels and legend
plt.title('Differences Between Actual and Predicted Values For Women\'s Body Fat Percentage', fontsize=16)
plt.xlabel('Test Record Index', fontsize=12)
plt.ylabel('Difference', fontsize=12)
plt.legend(fontsize=12)
plt.grid(alpha=0.3)
plt.show()
# Out:
# 83.78% of predictions have a difference of lower than three with actual values.

# %%
# Select a random test record
test_index = np.random.randint(0, len(X_test))  # Random index from the test set
test_record = X_test[test_index].reshape(1, -1)  # Reshape for prediction
actual_value = y_test.iloc[test_index]  # Corresponding actual value

# Predict using the model
predicted_value = model.predict(test_record, verbose=0)

# Print the results
print(f"Predicted Body Fat Percentage: {predicted_value[0][0]:.2f}")
print(f"Actual Body Fat Percentage: {actual_value:.2f}")
print(f"Differece: {abs(predicted_value[0][0] - actual_value):.2f}")
# Out:
# Predicted Body Fat Percentage: 17.24
# Actual Body Fat Percentage: 18.13
# Differece: 0.89
